# %% [markdown]
# <a href="https://colab.research.google.com/github/MoonlightO2/Our-World-in-Data/blob/main/World_Data_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
file = '/content/drive/MyDrive/Projects/Portfolio/Nature & Weather/Greenhouse Gas/World data I.csv'

# %%
data = pd.read_csv(file)
print('Shape: ', data.shape, '\n')
print('Columns: ', data.columns.tolist(), '\n')
data.head()
# Out:
# Shape:  (190, 8)
#
# Columns:  ['Country Region', ' Country', ' Population', ' GDP (USD)', 'Trillion & Billion (Text)', ' GDP Amount (USD)', 'Trillion & Billion (Int)', ' Development Status']
#   Country Region                      Country   Population   GDP (USD)  \
# 0         Africa                 South Africa     59622350      351.43
# 1           Asia                       Israel      8655535      387.47
# 2           Asia                        Japan    125584838        5.15
# 3           Asia                  South Korea     51322147        1.63
# 4           Asia   United Arab Emirates (UAE)      9890400      421.14
#
#   Trillion & Billion (Text)   GDP Amount (USD) Trillion & Billion (Int)  \
# 0                   billion       3.510000e+11            1,000,000,000
# 1                   billion       3.870000e+11            1,000,000,000
# 2                  Trillion       5.150000e+12        1,000,000,000,000
# ...
